# %% [markdown]
# # Olympics Database
# ## PART 1 - Upload and prepare the dataframe<br>PART 1 - Télécharger et préparer la base de données
# #### ENG<br>Start with importing the libraries needed<br>And then upload the data
#
# #### FR<br>Commençons par importer les librairies que nous allons utiliser<br>Puis téléchargeons la base de données

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/SportsScience-with-RL/Olympics/main/summer.csv'
df_main = pd.read_csv(url)

df_main
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# #### ENG<br>Look to basic informations of the dataframe
#
# #### FR<br>Regardons quelques informations de base de nos données

# %%
df_main.shape
# Out:
# (31165, 9)

# %%
df_main.dtypes
# Out:
# Year           int64
# City          object
# Sport         object
# Discipline    object
# Athlete       object
# Country       object
# Gender        object
# Event         object
# Medal         object
# dtype: object

# %%
#Look for missing values
#Cherchons des valeurs manquantes
df_main.isnull().sum()
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       4
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %%
null_df = df_main[df_main.isnull().any(axis=1)]
null_df
#It seems with a quick research we can fix this
#Avec une recherche sur internet nous pouvons retrouver ces valeurs manquantes
# Out:
#        Year    City          Sport           Discipline          Athlete  \
# 29603  2012  London      Athletics            Athletics          Pending
# 31072  2012  London  Weightlifting        Weightlifting          Pending
# 31091  2012  London  Weightlifting        Weightlifting          Pending
# 31110  2012  London      Wrestling  Wrestling Freestyle  KUDUKHOV, Besik
#
#       Country Gender     Event   Medal
# 29603     NaN  Women     1500M    Gold
# 31072     NaN  Women      63KG    Gold
# 31091     NaN    Men      94KG  Silver
# 31110     NaN    Men  Wf 60 KG  Silver

# %%
df_main.loc[29603, 'Athlete'] = 'YUSUF JAMAL, Maryam'
df_main.loc[29603, 'Country'] = 'BRN'

df_main.loc[31072, 'Athlete'] = 'GIRARD, Christine'
df_main.loc[31072, 'Country'] = 'CAN'

df_main.loc[31091, 'Athlete'] = 'KIM, Minjae'
df_main.loc[31091, 'Country'] = 'KOR'

df_main.loc[31110, 'Country'] = 'RUS'

# %%
#Check again
#Vérifions à nouveau
df_main.isnull().sum()
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       0
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %%
#Look for duplicates
#Cherchons des lignes dupliquées
df_main.duplicated().sum()
df_main.loc[df_main.duplicated(keep=False)]
# Out:
#        Year    City      Sport Discipline       Athlete Country Gender  \
# 16098  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 16099  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 29779  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
# 29785  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
#
#          Event Medal
# 16098   Hockey  Gold
# 16099   Hockey  Gold
# 29779  Doubles  Gold
# 29785  Doubles  Gold

# %%
#Keep just one of each duplicate
#Gardons une seule de chaque ligne dupliquée
df_main.drop_duplicates(keep='first', inplace=True)
df_main.reset_index(drop=True, inplace=True)
df_main.shape
# Out:
# (31163, 9)

# %%
#Save to a new csv
#Sauvergadeons sous un autre fichier csv
df_main.to_csv('C:/Users/raflg/Downloads/Databases/summer_arranged.csv')
